# %%
import json
import numpy as np
game1 = json.load(open('warriors_game1.json'))
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from imageio import imread

# %%
# %matplotlib notebook


def update_line(num, data, line):
    line.set_data(data[..., num])
    return line,

fig1 = plt.figure(figsize =(12,6))
img = imread("court.png")
plt.imshow(img,zorder=0, extent = [-54.5,54.5,-31.3,31.3])



bx = game1['2017/10/17/HOUGSW/']['ballXyz']['x'][2000:5000]
by = game1['2017/10/17/HOUGSW/']['ballXyz']['y'][2000:5000]

p1x = game1['2017/10/17/HOUGSW/']['homeplayers']['StephenCurry']['x'][2000:5000]
p1y = game1['2017/10/17/HOUGSW/']['homeplayers']['StephenCurry']['y'][2000:5000]


p2x = game1['2017/10/17/HOUGSW/']['homeplayers']['ZazaPachulia']['x'][2000:5000]
p2y = game1['2017/10/17/HOUGSW/']['homeplayers']['ZazaPachulia']['y'][2000:5000]

p3x = game1['2017/10/17/HOUGSW/']['homeplayers']['KevinDurant']['x'][2000:5000]
p3y = game1['2017/10/17/HOUGSW/']['homeplayers']['KevinDurant']['y'][2000:5000]

p4x = game1['2017/10/17/HOUGSW/']['homeplayers']['DraymondGreen']['x'][2000:5000]
p4y = game1['2017/10/17/HOUGSW/']['homeplayers']['DraymondGreen']['y'][2000:5000]

p5x = game1['2017/10/17/HOUGSW/']['homeplayers']['KlayThompson']['x'][2000:5000]
p5y = game1['2017/10/17/HOUGSW/']['homeplayers']['KlayThompson']['y'][2000:5000]

p6x = game1['2017/10/17/HOUGSW/']['awayplayers']['ChrisPaul']['x'][2000:5000]
p6y = game1['2017/10/17/HOUGSW/']['awayplayers']['ChrisPaul']['y'][2000:5000]

p7x = game1['2017/10/17/HOUGSW/']['awayplayers']['TrevorAriza']['x'][2000:5000]
p7y = game1['2017/10/17/HOUGSW/']['awayplayers']['TrevorAriza']['y'][2000:5000]

p8x = game1['2017/10/17/HOUGSW/']['awayplayers']['ClintCapela']['x'][2000:5000]
p8y = game1['2017/10/17/HOUGSW/']['awayplayers']['ClintCapela']['y'][2000:5000]

p9x = game1['2017/10/17/HOUGSW/']['awayplayers']['RyanAnderson']['x'][2000:5000]
p9y = game1['2017/10/17/HOUGSW/']['awayplayers']['RyanAnderson']['y'][2000:5000]

p10x = game1['2017/10/17/HOUGSW/']['awayplayers']['JamesHarden']['x'][2000:5000]
p10y = game1['2017/10/17/HOUGSW/']['awayplayers']['JamesHarden']['y'][2000:5000]


















data = np.array([bx,by])
l, = plt.plot([], [], 'ko', label = 'ball')
plt.xlim(-50, 50) 
plt.ylim(-30,30)
plt.xlabel('Court')
plt.title('Game Animation')
img = imread("court.png")
plt.imshow(img,zorder=0, extent = [-54.5,54.5,-31.3,31.3])

line_ani = animation.FuncAnimation(fig1, update_line, (len(bx)), fargs=(data, l),
                                   interval=65, blit=True)





data1 = np.array([p1x,p1y])
l1, = plt.plot([], [], 'bo', label = 'Warriors')

line_ani1 = animation.FuncAnimation(fig1, update_line, len(p1x), fargs=(data1, l1),
                                   interval=65, blit=True)

data2 = np.array([p2x,p2y])
l2, = plt.plot([], [], 'bo')

line_ani2 = animation.FuncAnimation(fig1, update_line, len(p2x), fargs=(data2, l2),
                                   interval=65, blit=True)

data3 = np.array([p3x,p3y])
l3, = plt.plot([], [], 'bo')

line_ani3 = animation.FuncAnimation(fig1, update_line, len(p3x), fargs=(data3, l3),
                                   interval=65, blit=True)


data4 = np.array([p4x,p4y])
l4, = plt.plot([], [], 'bo')

line_ani4 = animation.FuncAnimation(fig1, update_line, len(p4x), fargs=(data4, l4),
                                   interval=65, blit=True)


data5 = np.array([p5x,p5y])
l5, = plt.plot([], [], 'bo')

line_ani5 = animation.FuncAnimation(fig1, update_line, len(p5x), fargs=(data5, l5),
                                   interval=65, blit=True)


data6 = np.array([p6x,p6y])
l6, = plt.plot([], [], 'ro', label = 'Rockets')

line_ani6 = animation.FuncAnimation(fig1, update_line, len(p6x), fargs=(data6, l6),
                                   interval=65, blit=True)

data7 = np.array([p7x,p7y])
l7, = plt.plot([], [], 'ro')

line_ani7 = animation.FuncAnimation(fig1, update_line, len(p7x), fargs=(data7, l7),
                                   interval=65, blit=True)

data8 = np.array([p8x,p8y])
l8, = plt.plot([], [], 'ro')

line_ani8 = animation.FuncAnimation(fig1, update_line, len(p8x), fargs=(data8, l8),
                                   interval=65, blit=True)


data9 = np.array([p9x,p9y])
l9, = plt.plot([], [], 'ro')

line_ani9 = animation.FuncAnimation(fig1, update_line, len(p9x), fargs=(data9, l9),
                                   interval=65, blit=True)


data10 = np.array([p10x,p10y])
l10, = plt.plot([], [], 'ro')

line_ani10 = animation.FuncAnimation(fig1, update_line, len(p10x), fargs=(data10, l10),
                                   interval=65, blit=True)





plt.legend(loc='best')
# Out:
# <img src="data:image/png;base64,..." width="1200">
